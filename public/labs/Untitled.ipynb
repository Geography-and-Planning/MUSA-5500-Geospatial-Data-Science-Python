# %%
# Start with the usual imports
# We'll use these throughout
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
# Make the request
url = "https://www.drought.gov/current-conditions"
response = requests.get(url)

# Initialize the soup for this page
soup2 = BeautifulSoup(response.content, "html.parser")

# %%
selector = "#block-uswds-drought-content > div > div > div.grid-container.grid-container--standard.padding-top-6 > div:nth-child(5) > div > div:nth-child(3) > div > div > div.u--color--accent.text-center.font-sans-xl.field.field--name-field-number-stat.field--type-string.field--label-hidden"

# selector="u--color--accent text-center font-sans-xl field field--name-field-number-stat field--type-string field--label-hidden"



selector = "#block-uswds-drought-content > div > div > div.grid-container.grid-container--standard.padding-top-6 > div:nth-child(5) > div > div:nth-child(3) > div > div > div.u--color--accent.text-center.font-sans-xl.field.field--name-field-number-stat.field--type-string.field--label-hidden"


soup2.select_one(selector).text
# Out:
# '149.3 Million'

# %%
#block-uswds-drought-content > div > div > div.grid-container.grid-container--standard.padding-top-6 > div:nth-child(5) > div > div:nth-child(2) > div > div > div.u--color--accent.text-center.font-sans-xl.field.field--name-field-number-stat.field--type-string.field--label-hidden

# %%
#inspection_unit_0

# %%
<div data-pid="7890716517" class="cl-search-result cl-search-view-mode-gallery" title="FIRST MONTH FREE* Twin home with new carpet &amp; paint, dishwasher, garag"><div class="gallery-card"><div class="cl-gallery"><div class="gallery-inner"><a class="main" href="https://philadelphia.craigslist.org/apa/d/springfield-first-month-free-twin-home/7890716517.html"><div class="swipe" style="visibility: visible;"><div class="swipe-wrap" style="width: 3504px;"><div data-index="0" style="left: 0px; transition-duration: 0ms; transform: translateX(0px); width: 438px;"><span class="loading icom-"></span><img alt="FIRST MONTH FREE* Twin home with new carpet &amp; paint, dishwasher, garag 1" src="https://images.craigslist.org/d/7890716517/00D0D_cMpwEE8necL_0qc0hq_600x450.jpg" data-image-index="0"></div><div data-index="1" style="left: -438px; transition-duration: 0ms; transform: translateX(438px); width: 438px;"></div><div data-index="2" style="left: -876px; transition-duration: 0ms; transform: translateX(438px); width: 438px;"></div><div data-index="3" style="left: -1314px; transition-duration: 0ms; transform: translateX(-438px); width: 438px;"></div></div></div><div class="slider-back-arrow icom-"></div><div class="slider-forward-arrow icom-"></div></a></div><div class="dots"><span class="dot selected">•</span><span class="dot">•</span><span class="dot">•</span><span class="dot">•</span></div></div><a tabindex="0" href="https://philadelphia.craigslist.org/apa/d/springfield-first-month-free-twin-home/7890716517.html" class="cl-app-anchor cl-search-anchor text-only posting-title"><span class="label">FIRST MONTH FREE* Twin home with new carpet &amp; paint, dishwasher, garag</span></a><div class="meta-line"><button type="button" tabindex="0" class="bd-button cl-favorite-button icon-only" title="add to favorites list"><span class="icon icom-"></span></button><div class="meta">9 mins ago<span class="separator"></span><span class="housing-meta"><span class="post-bedrooms">3br</span><span class="post-sqft">1224ft<span class="exponent">2</span></span></span><span class="separator"></span>237 Pancoast Ave., Springfield, PA</div><button type="button" tabindex="0" class="bd-button cl-banish-button icon-only" title="hide posting"><span class="icon icom-"></span></button></div><span class="priceinfo">$2,000</span></div></div>
